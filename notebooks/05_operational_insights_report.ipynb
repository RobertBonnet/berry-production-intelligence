# %% [markdown]
# # Operational Insights Report

# %% [markdown]
# ## Business Objective

# %% [markdown]
# Analyze berry farm production data to generate insights.

# %%
import pandas as pd

data = pd.read_csv("../data/farm_production_data.csv")

data["yield_efficiency"] = data["actual_yield_kg"] / data["expected_yield_kg"]

data.groupby("berry_type")["yield_efficiency"].mean()
# Out:
# berry_type
# Blackberry    0.957447
# Blueberry     0.942623
# Raspberry     1.023256
# Strawberry    0.995962
# Name: yield_efficiency, dtype: float64
